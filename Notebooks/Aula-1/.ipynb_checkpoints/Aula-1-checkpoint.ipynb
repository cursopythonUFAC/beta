# %% [markdown]
# # Aula 1: Primeiros passos
#
# ## Guia de instalação do Python
#
# Existem várias maneiras de instalar o Python na sua máquina. Uma das maneiras mais práticas é através do Anaconda. Primeiramente acesse o site:
#
# https://www.anaconda.com/products/individual
#
# Procure por **Download** e baixe o instalador:
#
# ![Site do Jupyter](attachment:51baa1e1-7b11-41ac-a7d0-061c734f8fd9.png)
#
# Depois siga os passos como a instalação de qualquer outro programa do windows. Contudo, atente-se para selecionar `Add Anaconda3 to my PATH environmental variable`, como mostrado na figura abaixo:
#
# ![image.png](attachment:e98a7ed1-1468-4267-9414-63abd9335c2c.png)

# %% [markdown]
# Exemplo de cabeçalho no **Markdown**:
# ```markdown
# # Aula 1: Primeiros passos
# **Nome**: Todinho da Silva
# **E-mail**: todinho.silva@cursodepython.ufac
# ```
#
# Exemplo de cabeçalho no **Python**:
# ```python
# #------------------------------------------------
# # Aula 1: Primeiros passos
# #
# ```

# %%
nome = "Lucas Lima Rodrigues"
email = "lucaslrodri@gmail.com"
pi = 3.1415
raio = float(input('Digite o valor do raio para calcular o círculo:'))

AreaCirculo = pi*raio**2
print('O valor da área do círculo é: ',AreaCirculo,' m')



# Quadrado
#
# Out:
# Digite o valor do raio para calcular o círculo: 2
# O valor da área do círculo é:  12.566  m
